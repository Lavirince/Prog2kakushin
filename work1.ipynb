# %% [markdown]
# <a href="https://colab.research.google.com/github/Lavirince/Prog2kakushin/blob/main/work1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **乱数の分布、2つの乱数の平均の分布、3つの…… と平均化した時の分布をグラフ化する。**

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
def add_n(n):#乱数をn回足し、平均するプログラム
  ran = np.random.uniform(0.0, 1.0,400)#乱数の生成
  for x in range(n-1):
    a = np.random.uniform(0.0, 1.0,400)#乱数の生成
    ran += a
  ran /= n
  return ran

df1 = pd.DataFrame()#DF作成

ret = 7
ret +=1
for i in range(1,ret):#ret個のヒストグラム作成
  num = add_n(i)
  if i == 1:
    for x in range(400):#df1にappend(i=1)
      df1 = df1.append( {f'number{i}':num[x]}, ignore_index=True )
  else:
    for x in range(400):#df1にappend(i!=1)
      df1[f'number{i}'] = num
S = []#bins
for x in range(21):
  S.append(0.05*x)#bins
for i in range(1,ret):
  plt.hist(df1[f'number{i}'],bins=S)
  plt.show()

for i in range(1,ret):
  a = df1[f'number{i}'].mean()
  b = df1[f'number{i}'].var()
  c = df1[f'number{i}'].std()
  print('{}個の乱数の平均分布：平均{:.4f}、偏差{:.4f}、標準偏差{:.4f}'.format(i,a,b,c))
# Out:
# 1個の乱数の平均分布：平均0.4891、偏差0.0829、標準偏差0.2880
# 2個の乱数の平均分布：平均0.4941、偏差0.0427、標準偏差0.2067
# 3個の乱数の平均分布：平均0.4966、偏差0.0277、標準偏差0.1663
# 4個の乱数の平均分布：平均0.5094、偏差0.0216、標準偏差0.1468
# 5個の乱数の平均分布：平均0.4920、偏差0.0166、標準偏差0.1290
# 6個の乱数の平均分布：平均0.4966、偏差0.0140、標準偏差0.1183
# 7個の乱数の平均分布：平均0.4984、偏差0.0133、標準偏差0.1154
